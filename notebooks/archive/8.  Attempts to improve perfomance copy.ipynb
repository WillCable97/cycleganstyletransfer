# %% [markdown]
# ## Get a simple data set object together

# %%
import tensorflow as tf
from keras.layers import Conv2D, LeakyReLU, Input, MaxPooling2D, Activation, Conv2DTranspose, Concatenate, Dropout
from keras.models import Model, Sequential
import keras
import matplotlib.pyplot as plt

# %%
#Make the dataset
from cycleganstyletransfer.config import DATA_DIR
data_dir = DATA_DIR / "raw"


my_monet_ds_train, my_monet_ds_val = tf.keras.utils.image_dataset_from_directory(
    data_dir / "Monet",
    validation_split=0.2,
    subset="both",
    seed=42,
    image_size=(128, 128),
    batch_size = 1,
    labels = None,
)

my_image_ds_train, my_image_ds_val = tf.keras.utils.image_dataset_from_directory(
    data_dir / "Images",
    validation_split=0.2,
    subset="both",
    seed=42,
    image_size=(128, 128),
    batch_size = 1,
    labels = None,
)

my_monet_ds_train = my_monet_ds_train.map(lambda x: (x / 127.5) - 1)
my_image_ds_train = my_image_ds_train.map(lambda x: (x / 127.5) - 1)
    
DATASET_HEIGHT = max(len(my_monet_ds_train), len(my_image_ds_train))

my_monet_ds_train = iter(my_monet_ds_train.shuffle(42).repeat())
my_image_ds_train = iter(my_image_ds_train.shuffle(42).repeat())
# Out:
# Found 1193 files belonging to 1 classes.
# Using 955 files for training.
# Using 238 files for validation.
# Found 7037 files belonging to 1 classes.
# Using 5630 files for training.
# Using 1407 files for validation.

# %% [markdown]
# ## Put the Discrim model together (With regularization)

# %%
def build_discriminator(input_shape=(128, 128, 3)):
    inputs = Input(shape=input_shape)
    
    # First layer doesn't use instance normalization
    x = Conv2D(16, 3,padding='same')(inputs)
    x = LeakyReLU(0.2)(x)
    x = Dropout(0.3)(x)
    x = MaxPooling2D(2)(x)

    x = Conv2D(32, 3,padding='same')(x)
    x = LeakyReLU(0.2)(x)
    x = Dropout(0.3)(x)
    x = MaxPooling2D(2)(x)

    x = Conv2D(64, 3,padding='same')(x)
    x = LeakyReLU(0.2)(x)
    x = MaxPooling2D(2)(x)

    x = Conv2D(1, 3, padding='same')(x)
    
    return Model(inputs, x, name='discriminator')

my_discriminator = build_discriminator()
my_discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 16)      448
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 16)      0
#
#  dropout_8 (Dropout)         (None, 128, 128, 16)      0
#
#  max_pooling2d_12 (MaxPooli  (None, 64, 64, 16)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 32)        4640
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 64, 64, 32)        0
#
#  dropout_9 (Dropout)         (None, 64, 64, 32)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 32, 32, 32)        0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 64)        18496
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  max_pooling2d_14 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 1)         577
#
# =================================================================
# Total params: 24161 (94.38 KB)
# Trainable params: 24161 (94.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Generator model

# %%
class InstanceNormalization(keras.layers.Layer):
    def __init__(self, epsilon=1e-5, **kwargs):
        super(InstanceNormalization, self).__init__(**kwargs)
        self.epsilon = epsilon

    def build(self, input_shape):
        # One scale and bias per channel
        self.gamma = self.add_weight(
            shape=(input_shape[-1],),
            initializer='ones',
            trainable=True,
            name='gamma'
        )
        self.beta = self.add_weight(
            shape=(input_shape[-1],),
            initializer='zeros',
            trainable=True,
            name='beta'
        )
        super(InstanceNormalization, self).build(input_shape)

    def call(self, inputs):
        # Compute mean and variance per instance, per channel
        mean, variance = tf.nn.moments(inputs, axes=[1, 2], keepdims=True)
        normalized = (inputs - mean) / tf.sqrt(variance + self.epsilon)
        return self.gamma * normalized + self.beta

    def get_config(self):
        config = super().get_config().copy()
        config.update({"epsilon": self.epsilon})
        return config

# %%
def DownSampleBlock(filters:int, kernel_size:int, strides:int):
    ret_block = Sequential()
    ret_block.add(Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same'))
    ret_block.add(InstanceNormalization())
    ret_block.add(Activation('relu'))
    return ret_block

# %%
import uuid

def UpSampleBlock(filters:int, kernel_size:int, strides:int):
    ret_block = Sequential(name=f'UpsampleBlock_{uuid.uuid4()}')
    ret_block.add(Conv2DTranspose(filters=filters, kernel_size=kernel_size, strides=strides, padding='same'))
    ret_block.add(InstanceNormalization())
    ret_block.add(Activation('relu'))
    return ret_block

# %%
def Generator(input_shape:tuple, kernel_size:int=3, strides:int=1
              ,filter_line:list[int]=[32,64,128]) -> keras.Model:
    networks_appending = []
    input_block = Input(shape=input_shape)
    ret_block = input_block

    #Create encoder chain
    for filter_choice in filter_line:
        ret_block=DownSampleBlock(filter_choice,3,2)(ret_block)
        networks_appending.append(ret_block)

    #Decoder with residual connections
    for filter_choice, network_append in zip(filter_line[::-1][1:], networks_appending[::-1][1:]):
        ret_block = UpSampleBlock(filter_choice, 3,2)(ret_block)
        ret_block = Concatenate()([ret_block, network_append])
    
    ret_block = Conv2DTranspose(input_shape[-1], kernel_size, strides, padding='same', activation='tanh')(ret_block)

    return Model(input_block, ret_block)

# %%
my_generator = Generator((128, 128, 3), strides=2)
my_generator.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  sequential_9 (Sequential)   (None, 64, 64, 32)           960       ['input_9[0][0]']
#
#  sequential_10 (Sequential)  (None, 32, 32, 64)           18624     ['sequential_9[0][0]']
#
#  sequential_11 (Sequential)  (None, 16, 16, 128)          74112     ['sequential_10[0][0]']
#
#  UpsampleBlock_95750189-3fd  (None, 32, 32, 64)           73920     ['sequential_11[0][0]']
#  5-4388-aaa2-b2f1e901009a (
#  Sequential)
#
#  concatenate_6 (Concatenate  (None, 32, 32, 128)          0         ['UpsampleBlock_95750189-3fd5-
#  )                                                                  4388-aaa2-b2f1e901009a[0][0]',
#                                                                      'sequential_10[0][0]']
#
#  UpsampleBlock_d5b7116e-e5b  (None, 64, 64, 32)           36960     ['concatenate_6[0][0]']
#  2-4e47-9cc3-6a3e9a4cd277 (
#  Sequential)
#
#  concatenate_7 (Concatenate  (None, 64, 64, 64)           0         ['UpsampleBlock_d5b7116e-e5b2-
#  )                                                                  4e47-9cc3-6a3e9a4cd277[0][0]',
#                                                                      'sequential_9[0][0]']
#
#  conv2d_transpose_11 (Conv2  (None, 128, 128, 3)          1731      ['concatenate_7[0][0]']
#  DTranspose)
#
# ==================================================================================================
# Total params: 206307 (805.89 KB)
# Trainable params: 206307 (805.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def my_square_loss(y_true, y_pred):
    y_true = tf.reshape(tf.cast(y_true, tf.float32), (-1, 1, 1, 1))
    y_true = tf.broadcast_to(y_true, tf.shape(y_pred))
    return tf.reduce_mean(tf.math.squared_difference(y_true, y_pred))

# %% [markdown]
# ## Introducing Generator loss

# %%
def generator_loss(descrim_output):
        return tf.reduce_mean(tf.math.squared_difference(tf.ones_like(descrim_output), descrim_output))

# %% [markdown]
# ## Adding Alternating trainin

# %%
from keras.optimizers import Adam
import numpy as np
import time

NUM_EPOCHS = 8
EPOCH_LENGTH = DATASET_HEIGHT
DISPLAY_INTERVAL = 15  # record loss every 5 steps

my_optimiser = Adam(learning_rate=0.0002, beta_1=0.5)
gen_optimiser = Adam(beta_1=0.5)

my_generator = Generator((128, 128, 3), strides=2)
my_discriminator = build_discriminator()

eg_image = next(my_image_ds_train)
eg_output = my_generator(eg_image)

all_losses = []

for i in range(NUM_EPOCHS):
    print(f"\nEpoch {i + 1}/{NUM_EPOCHS}")
    epoch_losses = []
    start_time = time.time()

    for j in range(EPOCH_LENGTH):
        monet_image = (next(my_monet_ds_train)) 
        real_image = (next(my_image_ds_train))
        # Display progress images every 100 steps

        if j % 1000 == 0:
            test_output = my_generator(real_image)
            plt.figure(figsize=(15, 5))
            plt.subplot(1, 2, 1)
            plt.imshow(real_image[0] * 0.5 + 0.5)  # Denormalize
            plt.title('Input Photo')
            plt.axis('off')
            
            plt.subplot(1, 2, 2)
            plt.imshow(test_output[0] * 0.5 + 0.5)  # Denormalize
            plt.title('Generated Monet-style Image')
            plt.axis('off')
            plt.show()
            plt.close()



        with tf.GradientTape(persistent=True) as tape:
            real_monet = monet_image
            fake_monet = my_generator(real_image)

            real_monet_output = my_discriminator(real_monet)
            fake_monet_output = my_discriminator(fake_monet)

            loss = 0.5 * (
                my_square_loss(tf.constant(1.0), real_monet_output) +
                my_square_loss(tf.constant(0.0), fake_monet_output)
            )

            monet_generator_loss = generator_loss(fake_monet_output)
        if j % 4 == 0 :
            grads = tape.gradient(loss, my_discriminator.trainable_variables)
            my_optimiser.apply_gradients(zip(grads, my_discriminator.trainable_variables))
        else:
            generator_grads =  tape.gradient(monet_generator_loss, my_generator.trainable_variables)
            gen_optimiser.apply_gradients(zip(generator_grads, my_generator.trainable_variables))

        if j % DISPLAY_INTERVAL == 0:
            disc_loss = tf.squeeze(loss).numpy()
            gen_loss = tf.squeeze(monet_generator_loss).numpy()
            epoch_losses.append((disc_loss, gen_loss))
        print(f"\rStep {j + 1}/{EPOCH_LENGTH} - discriminator loss: {epoch_losses[-1][0]:.4f}, generator loss: {epoch_losses[-1][1]:.4f}", end='')

    epoch_avg_disc_loss = np.mean([l[0] for l in epoch_losses])
    epoch_avg_gen_loss = np.mean([l[1] for l in epoch_losses])
    print(f"\nEpoch {i + 1} completed in {int(time.time() - start_time)}s - avg discriminator loss: {epoch_avg_disc_loss:.4f}, avg generator loss: {epoch_avg_gen_loss:.4f}")
    all_losses.extend(epoch_losses)
# Out:
# Epoch 1/8
# Step 1000/5630 - discriminator loss: 0.3548, generator loss: 0.2086
# Step 2000/5630 - discriminator loss: 0.3022, generator loss: 0.2414
# Step 3000/5630 - discriminator loss: 0.2838, generator loss: 0.2459
# Step 4000/5630 - discriminator loss: 0.2842, generator loss: 0.2330
# Step 5000/5630 - discriminator loss: 0.2561, generator loss: 0.2795
# Step 5630/5630 - discriminator loss: 0.2587, generator loss: 0.2393
# Epoch 1 completed in 1216s - avg discriminator loss: 0.2904, avg generator loss: 0.3177
#
# Epoch 2/8
# Step 1000/5630 - discriminator loss: 0.2905, generator loss: 0.2908
# Step 2000/5630 - discriminator loss: 0.2539, generator loss: 0.2446
# Step 3000/5630 - discriminator loss: 0.2639, generator loss: 0.2616
# Step 4000/5630 - discriminator loss: 0.2484, generator loss: 0.2194
# Step 5000/5630 - discriminator loss: 0.2568, generator loss: 0.2471
# Step 5630/5630 - discriminator loss: 0.2520, generator loss: 0.2605
# Epoch 2 completed in 2092s - avg discriminator loss: 0.2571, avg generator loss: 0.2534
#
# Epoch 3/8
# Step 1000/5630 - discriminator loss: 0.2550, generator loss: 0.2476
# Step 2000/5630 - discriminator loss: 0.2522, generator loss: 0.2541
# Step 3000/5630 - discriminator loss: 0.2523, generator loss: 0.2495
# Step 4000/5630 - discriminator loss: 0.2519, generator loss: 0.2617
# Step 5000/5630 - discriminator loss: 0.2511, generator loss: 0.2574
# Step 5630/5630 - discriminator loss: 0.2521, generator loss: 0.2449
# Epoch 3 completed in 2504s - avg discriminator loss: 0.2525, avg generator loss: 0.2507
#
# Epoch 4/8
# Step 1000/5630 - discriminator loss: 0.2503, generator loss: 0.2394
# Step 2000/5630 - discriminator loss: 0.2518, generator loss: 0.2444
# Step 2494/5630 - discriminator loss: 0.2514, generator loss: 0.2445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25948\2790706238.py in ?()
#      61             grads = tape.gradient(loss, my_discriminator.trainable_variables)
#      62             my_optimiser.apply_gradients(zip(grads, my_discriminator.trainable_variables))
#      63         else:
#      64             generator_grads =  tape.gradient(monet_generator_loss, my_generator.trainable_variables)
# ---> 65             gen_optimiser.apply_gradients(zip(generator_grads, my_generator.trainable_variables))
#      66
#      67         if j % DISPLAY_INTERVAL == 0:
#      68             disc_loss = tf.squeeze(loss).numpy()
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1219             "experimental_aggregate_gradients", True
#    1220         )
#    1221         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223         return super().apply_gradients(grads_and_vars, name=name)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(self, grads_and_vars, name)
#     648             grads = self._clip_gradients(grads)
#     649             grads = self._deduplicate_sparse_grad(grads)
#     650             self._apply_weight_decay(trainable_variables)
#     651             grads_and_vars = list(zip(grads, trainable_variables))
# --> 652             iteration = self._internal_apply_gradients(grads_and_vars)
#     653
#     654             # Apply variable constraints after applying gradients.
#     655             for variable in trainable_variables:
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(self, grads_and_vars)
#    1249         if self._mesh or self._run_with_dtensor:
#    1250             # Skip any usage of strategy logic for DTensor
#    1251             return super()._internal_apply_gradients(grads_and_vars)
#    1252
# -> 1253         return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254             self._distributed_apply_gradients_fn,
#    1255             self._distribution_strategy,
#    1256             grads_and_vars,
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\distribute\merge_call_interim.py in ?(fn, strategy, *args, **kwargs)
#      47   Returns:
#      48     The return value of the `fn` call.
#      49   """
#      50   if strategy_supports_no_merge_call():
# ---> 51     return fn(strategy, *args, **kwargs)
#      52   else:
#      53     return distribute_lib.get_replica_context().merge_call(
#      54         fn, args=args, kwargs=kwargs)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(self, distribution, grads_and_vars, **kwargs)
#    1341             else:
#    1342                 return self._update_step(grad, var)
#    1343
#    1344         for grad, var in grads_and_vars:
# -> 1345             distribution.extended.update(
#    1346                 var, apply_grad_to_update_var, args=(grad,), group=False
#    1347             )
#    1348
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, var, fn, args, kwargs, group)
#    3007         _get_default_replica_context()):
#    3008       fn = autograph.tf_convert(
#    3009           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3010       with self._container_strategy().scope():
# -> 3011         return self._update(var, fn, args, kwargs, group)
#    3012     else:
#    3013       return self._replica_ctx_update(
#    3014           var, fn, args=args, kwargs=kwargs, group=group)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, var, fn, args, kwargs, group)
#    4078   def _update(self, var, fn, args, kwargs, group):
#    4079     # The implementations of _update() and _update_non_slot() are identical
#    4080     # except _update() passes `var` as the first argument to `fn()`.
# -> 4081     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, colocate_with, fn, args, kwargs, should_group)
#    4083   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4084     # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4085     # once that value is used for something.
#    4086     with UpdateContext(colocate_with):
# -> 4087       result = fn(*args, **kwargs)
#    4088       if should_group:
#    4089         return result
#    4090       else:
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(var, grad)
#    1338         def apply_grad_to_update_var(var, grad):
#    1339             if self.jit_compile:
#    1340                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341             else:
# -> 1342                 return self._update_step(grad, var)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\optimizer.py in ?(self, gradient, variable)
#     237                 "`optimizer.build(variables)` with the full list of trainable "
#     238                 "variables before the training loop or use legacy optimizer "
#     239                 f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240             )
# --> 241         self.update_step(gradient, variable)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\keras\src\optimizers\adam.py in ?(self, gradient, variable)
#     170         var_key = self._var_key(variable)
#     171         m = self._momentums[self._index_dict[var_key]]
#     172         v = self._velocities[self._index_dict[var_key]]
#     173
# --> 174         alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     175
#     176         if isinstance(gradient, tf.IndexedSlices):
#     177             # Sparse gradients.
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(y, x)
#    1508     with ops.name_scope(None, op_name, [x, y]) as name:
#    1509       # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1510       #   r_binary_op_wrapper use different force_same_dtype values.
#    1511       y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1512       return func(x, y, name=name)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     544 @tf_export("math.subtract", "subtract")
#     545 @dispatch.register_binary_elementwise_api
#     546 @dispatch.add_dispatch_support
#     547 def subtract(x, y, name=None):
# --> 548   return gen_math_ops.sub(x, y, name)
#
# c:\Users\willi\Anaconda3\envs\tf310\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#   13535         _ctx, "Sub", name, x, y)
#   13536       return _result
#   13537     except _core._NotOkStatusException as e:
#   13538       _ops.raise_from_not_ok_status(e, name)
# > 13539     except _core._FallbackException:
#   13540       pass
#   13541     try:
#   13542       return sub_eager_fallback(
#
# KeyboardInterrupt:

# %%
# Plot full training loss curves
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
disc_losses = [l[0] for l in all_losses]
plt.plot(disc_losses[5:])
plt.title('Discriminator Loss Over Training')
plt.xlabel(f'Steps (every {DISPLAY_INTERVAL} batches)')
plt.ylabel('Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
gen_losses = [l[1] for l in all_losses]
plt.plot(gen_losses)
plt.title('Generator Loss Over Training')
plt.xlabel(f'Steps (every {DISPLAY_INTERVAL} batches)')
plt.ylabel('Loss')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Plot full training loss curves
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.imshow(eg_image[0] * 0.5 + 0.5)  # Normalize the image from [0,255] to [0,1] for display
plt.axis('off')
plt.title('Example Training Image')


plt.subplot(1, 2, 2)
plt.imshow(eg_output[0] * 0.5 + 0.5)  # Denormalize the image for display
plt.axis('off')
plt.title('Example Training Image')


plt.tight_layout()
plt.show()

# %%
eg_output2 = my_generator(eg_image)

# %%
# Plot full training loss curves
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.imshow(eg_image[0] * 0.5 + 0.5)  # Normalize the image from [0,255] to [0,1] for display
plt.axis('off')
plt.title('Example Training Image')


plt.subplot(1, 2, 2)
plt.imshow(eg_output2[0] * 0.5 + 0.5)  # Denormalize the image for display
plt.axis('off')
plt.title('Example Training Image')


plt.tight_layout()
plt.show()

# %%
from keras.optimizers import Adam
import numpy as np
import time

NUM_EPOCHS = 3
EPOCH_LENGTH = DATASET_HEIGHT // 3
DISPLAY_INTERVAL = 5  # record loss every 5 steps

my_optimiser = Adam(learning_rate=0.0002, beta_1=0.5)

my_generator = Generator((128, 128, 3), strides=2)
my_discriminator = build_discriminator()

all_losses = []

for i in range(NUM_EPOCHS):
    print(f"\nEpoch {i + 1}/{NUM_EPOCHS}")
    epoch_losses = []
    start_time = time.time()

    for j in range(EPOCH_LENGTH):
        monet_image = (next(my_monet_ds_train)) 
        real_image = (next(my_image_ds_train))

        with tf.GradientTape() as tape:
            monet_output = my_discriminator(monet_image)
            image_output = my_discriminator(real_image)

            loss = 0.5 * (
                my_square_loss(tf.constant(1.0), monet_output) +
                my_square_loss(tf.constant(0.0), image_output)
            )

        grads = tape.gradient(loss, my_discriminator.trainable_variables)
        my_optimiser.apply_gradients(zip(grads, my_discriminator.trainable_variables))

        if j % DISPLAY_INTERVAL == 0:
            epoch_losses.append(tf.squeeze(loss).numpy())
        print(f"\rStep {j + 1}/{EPOCH_LENGTH} - loss: {epoch_losses[-1]:.4f}", end='')

    epoch_avg_loss = np.mean(epoch_losses)
    print(f"\nEpoch {i + 1} completed in {int(time.time() - start_time)}s - avg loss: {epoch_avg_loss:.4f}")
    all_losses.extend(epoch_losses)

# Plot full training loss curve
plt.figure(figsize=(10, 5))
plt.plot(all_losses)
plt.title('Discriminator Loss Over Training')
plt.xlabel(f'Steps (every {DISPLAY_INTERVAL} batches)')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
